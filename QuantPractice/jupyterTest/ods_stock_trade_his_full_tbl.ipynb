# %%
import akshare as ak
import numpy as np
import pandas as pd
# Out:
# C:\Users\Michelle\anaconda3\lib\site-packages\akshare\__init__.py:2690: UserWarning: 为了支持更多特性，请将 Pandas 升级到 2.1.0 及以上版本！
#   warnings.warn(

# %%
df = ak.stock_zh_a_hist(symbol="000001", period="daily", start_date="19700101", end_date='20500101',
                                        adjust="qfq")

# %%
df.head()
# Out:
#            日期    开盘    收盘    最高    最低  成交量      成交额   振幅   涨跌幅   涨跌额  换手率
# 0  1991-04-03 -1.25 -1.25 -1.25 -1.25    1   5000.0  0.0  4.58  0.06  0.0
# 1  1991-04-04 -1.25 -1.25 -1.25 -1.25    3  15000.0  0.0  0.00  0.00  0.0
# 2  1991-04-05 -1.25 -1.25 -1.25 -1.25    2  10000.0  0.0  0.00  0.00  0.0
# 3  1991-04-06 -1.25 -1.25 -1.25 -1.25    7  34000.0  0.0  0.00  0.00  0.0
# 4  1991-04-08 -1.26 -1.26 -1.26 -1.26    2  10000.0  0.0 -0.80 -0.01  0.0

# %%
df.tail()
# Out:
#               日期     开盘     收盘     最高     最低      成交量           成交额     振幅  \
# 7851  2024-02-08   9.58   9.67   9.67   9.52  1656814  1.593506e+09   1.56
# 7852  2024-02-19   9.76   9.81   9.81   9.65  1605243  1.564088e+09   1.65
# 7853  2024-02-20   9.79   9.82   9.84   9.73  1123564  1.098988e+09   1.12
# 7854  2024-02-21   9.78  10.80  10.80   9.77  5055285  5.295259e+09  10.49
# 7855  2024-02-22  10.65  10.90  10.91  10.62  4922325  5.307736e+09   2.69
#
#        涨跌幅   涨跌额   换手率
# 7851  0.62  0.06  0.85
# 7852  1.45  0.14  0.83
# 7853  0.10  0.01  0.58
# 7854  9.98  0.98  2.61
# 7855  0.93  0.10  2.54

# %%
# 历史行情数据-不复权
stock_zh_a_hist_df = ak.stock_zh_a_hist(symbol="000001", period="daily", start_date="20200101", end_date='20230515', adjust="")
stock_zh_a_hist_df
# 历史行情数据-前复权
stock_zh_a_hist_df = ak.stock_zh_a_hist(symbol="000001", period="daily", start_date="20200101", end_date='20230515', adjust="qfq")
stock_zh_a_hist_df
# 历史行情数据-后复权
stock_zh_a_hist_df = ak.stock_zh_a_hist(symbol="000001", period="daily", start_date="20200101", end_date='20230515', adjust="hfq")
stock_zh_a_hist_df
# Out:
#              日期       开盘       收盘       最高       最低      成交量           成交额  \
# 0    2020-01-02  2810.25  2846.00  2859.00  2793.99  1530232  2.571196e+09
# 1    2020-01-03  2857.38  2896.38  2917.51  2854.13  1116195  1.914495e+09
# 2    2020-01-06  2868.75  2878.51  2922.39  2852.50   862084  1.477930e+09
# 3    2020-01-07  2888.26  2891.51  2912.64  2859.00   728608  1.247047e+09
# 4    2020-01-08  2867.13  2811.87  2875.26  2806.99   847824  1.423609e+09
# ..          ...      ...      ...      ...      ...      ...           ...
# 809  2023-05-09  2383.77  2344.77  2416.28  2339.89  2422534  3.238716e+09
# 810  2023-05-10  2346.39  2292.76  2361.02  2286.26  1237053  1.600190e+09
# 811  2023-05-11  2310.64  2294.38  2338.27  2286.26   903758  1.166479e+09
# 812  2023-05-12  2289.51  2257.00  2297.63  2255.38   885604  1.124579e+09
# 813  2023-05-15  2266.75  2291.13  2294.38  2229.37   928326  1.173804e+09
#
#        振幅   涨跌幅    涨跌额   换手率
# 0    2.34  2.46  68.26  0.79
# ...

# %%
# 下载并可视化
# 选取4个股票（不复权），放在同一个坐标轴里面展示。

# 股票列表
stock_codes = ["000001","600489","600028","601988"]

# 定义日期范围
start_date = '20230101' # 这样定义无效，必须手动收入
end_date = '20240110' # 这样定义无效，必须手动收入

# %%
road = []
# 遍历股票代码，并获取历史数据
for stock_code in stock_codes:
    # 使用 akshare 获取股票历史数据
    stock_data = ak.stock_zh_a_hist(symbol=stock_code,  period="daily", start_date="20200101", end_date='20230515', adjust="")
    
    # 日期是object格式，转化成日期格式
    stock_data['日期'] = pd.to_datetime( stock_data ['日期'] )
    
    # 用日期做索引，避免因停牌等情况发生时，导致合并后的数据存在缺失。
    stock_data.set_index( '日期' , inplace=True )
    
    # 重新定义列名，不重新定义的话就写成 多级列名切片
    stock_data.columns = stock_data.columns+stock_code
    road.append(stock_data)

# %%
# 多级列合并就用这个
# multiple_stock_data = pd.concat(road,axis=1,keys=stock_codes)

# 多数据合并
multiple_stock_data = pd.concat ( road , axis =1 )

# %%
multiple_stock_data.head()
# Out:
#             开盘000001  收盘000001  最高000001  最低000001  成交量000001     成交额000001  \
# 日期
# 2020-01-02     16.65     16.87     16.95     16.55    1530232  2.571196e+09
# 2020-01-03     16.94     17.18     17.31     16.92    1116195  1.914495e+09
# 2020-01-06     17.01     17.07     17.34     16.91     862084  1.477930e+09
# 2020-01-07     17.13     17.15     17.28     16.95     728608  1.247047e+09
# 2020-01-08     17.00     16.66     17.05     16.63     847824  1.423609e+09
#
#             振幅000001  涨跌幅000001  涨跌额000001  换手率000001  ...  开盘601988  \
# 日期                                                     ...
# 2020-01-02      2.43       2.55       0.42       0.79  ...      3.71
# 2020-01-03      2.31       1.84       0.31       0.58  ...      3.73
# 2020-01-06      2.50      -0.64      -0.11       0.44  ...      3.70
# 2020-01-07      1.93       0.47       0.08       0.38  ...      3.69
# 2020-01-08      2.45      -2.86      -0.49       0.44  ...      3.71
#
# ...

# %%
# 把需要股票数据提取出来，看开盘价就写开盘，具体维度上期有图。
list_stock_K = [ '收盘' + x for x in stock_codes ]
df = multiple_stock_data[list_stock_K]

# %%
list_stock_K
# Out:
# ['收盘000001', '收盘600489', '收盘600028', '收盘601988']

# %%
df.head()
# Out:
#             收盘000001  收盘600489  收盘600028  收盘601988
# 日期
# 2020-01-02     16.87      8.51      5.17      3.72
# 2020-01-03     17.18      8.80      5.27      3.71
# 2020-01-06     17.07      9.40      5.36      3.69
# 2020-01-07     17.15      9.12      5.25      3.72
# 2020-01-08     16.66      9.52      5.28      3.69

# %%
# 当前股票数据
akspot = ak.stock_zh_a_spot_em()
akspot.head(2)
# Out:
#    序号      代码     名称   最新价    涨跌幅   涨跌额       成交量          成交额     振幅    最高  \
# 0   1  300209  ST有棵树  2.26  20.21  0.38   49655.0  11222030.00   0.00  2.26
# 1   2  300270   中威电子  5.74  20.08  0.96  168265.0  91513845.74  18.62  5.74
#
#    ...    量比   换手率  市盈率-动态    市净率           总市值          流通市值   涨速  5分钟涨跌  \
# 0  ...  0.57  1.26   -5.02 -19.92  9.539626e+08  8.920901e+08  0.0    0.0
# 1  ...  0.77  6.94  -24.30   2.48  1.738107e+09  1.392493e+09  0.0    0.0
#
#    60日涨跌幅  年初至今涨跌幅
# 0  -28.03   -19.29
# 1  -28.16   -25.65
#
# [2 rows x 23 columns]

# %%
akspot.head()
# Out:
#    序号      代码     名称    最新价    涨跌幅   涨跌额       成交量           成交额     振幅  \
# 0   1  300209  ST有棵树   2.26  20.21  0.38   49655.0  1.122203e+07   0.00
# 1   2  300270   中威电子   5.74  20.08  0.96  168265.0  9.151385e+07  18.62
# 2   3  300711   广哈通信  11.74  20.04  1.96   74634.0  8.469455e+07  18.40
# 3   4  300903   科翔股份   7.13  20.03  1.19  148549.0  1.011290e+08  20.20
# 4   5  301318    维海德  43.06  20.01  7.18  118734.0  5.010833e+08  10.67
#
#       最高  ...    量比    换手率  市盈率-动态    市净率           总市值          流通市值   涨速  \
# 0   2.26  ...  0.57   1.26   -5.02 -19.92  9.539626e+08  8.920901e+08  0.0
# 1   5.74  ...  0.77   6.94  -24.30   2.48  1.738107e+09  1.392493e+09  0.0
# 2  11.74  ...  0.98   3.01  130.24   4.43  2.925263e+09  2.910562e+09  0.0
# 3   7.13  ...  0.75   4.50  -36.52   1.29  2.956771e+09  2.351382e+09  0.0
# 4  43.06  ...  2.80  27.42   42.75   2.56  4.483321e+09  1.864788e+09  0.0
#
#    5分钟涨跌  60日涨跌幅  年初至今涨跌幅
# 0    0.0  -28.03   -19.29
# 1    0.0  -28.16   -25.65
# ...

# %%
filtered_df
# Out:
#         序号      代码    名称    最新价   涨跌幅   涨跌额        成交量           成交额    振幅  \
# 1764  1765  600028  中国石化   6.42  2.72  0.17  1854653.0  1.180108e+09  3.52
# 2218  2219  600489  中金黄金  10.47  2.15  0.22   479826.0  4.989506e+08  3.12
# 3500  3501  000001  平安银行  10.90  0.93  0.10  4922325.0  5.307736e+09  2.69
# 4613  4614  601988  中国银行   4.56  0.00  0.00  1529266.0  6.952816e+08  1.32
#
#          最高  ...    量比   换手率  市盈率-动态   市净率           总市值          流通市值    涨速  \
# 1764   6.45  ...  0.90  0.20   10.85  0.96  7.662222e+11  6.097201e+11 -0.16
# 2218  10.50  ...  0.85  0.99   18.37  2.04  5.075136e+10  5.075136e+10  0.10
# 3500  10.91  ...  2.14  2.54    4.00  0.53  2.115245e+11  2.115205e+11  0.18
# 4613   4.58  ...  0.48  0.07    5.76  0.62  1.342408e+12  9.610907e+11 -0.44
#
#       5分钟涨跌  60日涨跌幅  年初至今涨跌幅
# 1764   0.00   16.73    15.05
# 2218   0.10   -0.29     5.12
# 3500   0.18    6.03    16.08
# 4613  -0.22   14.86    14.29
#
# [4 rows x 23 columns]

# %%
# 使用 isin 函数进行筛选
# 重新定义stock_codes
filtered_df = akspot[akspot['代码'].isin( stock_codes )]
stock_codes = filtered_df['名称'].tolist()
# 股票代码转化成股票名称
df.columns = stock_codes

# %%
stock_codes
# Out:
# ['中国石化', '中金黄金', '平安银行', '中国银行']

# %%
df.head()
# Out:
#              中国石化  中金黄金  平安银行  中国银行
# 日期
# 2020-01-02  16.87  8.51  5.17  3.72
# 2020-01-03  17.18  8.80  5.27  3.71
# 2020-01-06  17.07  9.40  5.36  3.69
# 2020-01-07  17.15  9.12  5.25  3.72
# 2020-01-08  16.66  9.52  5.28  3.69

# %%
from pyecharts.charts import Line
from pyecharts import options as opts
# 创建 Line 实例
line = Line()

# 添加 x 轴数据（日期）
line.add_xaxis(df.index.strftime('%Y-%m-%d').tolist())

# 添加多个股票的 y 轴数据
# line.add_yaxis( stock_codes[0], df[list_stock_K[0]].tolist() ) 
# line.add_yaxis( stock_codes[1], df[list_stock_K[1]].tolist() )

# 循环添加股票的数据
for i in range( len( stock_codes ) ):
    line.add_yaxis(stock_codes[i] , df[stock_codes[i]].tolist())


# 设置图表标题、坐标轴标签等
line.set_global_opts(
    title_opts=opts.TitleOpts(title='Stock Prices'),
    xaxis_opts=opts.AxisOpts(name='Date'),
    yaxis_opts=opts.AxisOpts(name='Price')
)

# 渲染生成 HTML 文件（可选）
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1169f4c9e7744066a0ec8e5af87d29b0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1169f4c9e7744066a0ec8e5af87d29b0 = echarts.init(
#                     document.getElementById('1169f4c9e7744066a0ec8e5af87d29b0'), 'white', {renderer: 'canvas'});
#                 var option_1169f4c9e7744066a0ec8e5af87d29b0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %%
payh = ak.stock_zh_a_hist(symbol="000001", period="daily", start_date="19700101", end_date='20500907',
                                        adjust="qfq")
payh.head()
# Out:
#            日期    开盘    收盘    最高    最低  成交量      成交额   振幅   涨跌幅   涨跌额  换手率
# 0  1991-04-03 -1.25 -1.25 -1.25 -1.25    1   5000.0  0.0  4.58  0.06  0.0
# 1  1991-04-04 -1.25 -1.25 -1.25 -1.25    3  15000.0  0.0  0.00  0.00  0.0
# 2  1991-04-05 -1.25 -1.25 -1.25 -1.25    2  10000.0  0.0  0.00  0.00  0.0
# 3  1991-04-06 -1.25 -1.25 -1.25 -1.25    7  34000.0  0.0  0.00  0.00  0.0
# 4  1991-04-08 -1.26 -1.26 -1.26 -1.26    2  10000.0  0.0 -0.80 -0.01  0.0

# %%
payh.columns=["pdate","open","close","highest","lowest","volume","amount","vibration","updown","updown_yuan","turnover"]
payh["code"]=["000001" for i in range(len(payh))]

payh.head()
# Out:
#         pdate  open  close  highest  lowest  volume       amount  vibration  \
# 0  2017-03-01  8.14   8.14     8.20    8.12  346994  330157968.0       0.98
# 1  2017-03-02  8.16   8.08     8.19    8.07  403629  382395888.0       1.47
# 2  2017-03-03  8.06   8.05     8.08    8.01  342655  321952544.0       0.87
# 3  2017-03-06  8.05   8.10     8.11    8.04  404511  381212304.0       0.87
# 4  2017-03-07  8.09   8.10     8.11    8.05  294673  277747408.0       0.74
#
#    updown  updown_yuan  turnover    code
# 0    0.12         0.01      0.21  000001
# 1   -0.74        -0.06      0.24  000001
# 2   -0.37        -0.03      0.20  000001
# 3    0.62         0.05      0.24  000001
# 4    0.00         0.00      0.17  000001

# %%
payh=payh[["code", "pdate","open","close","highest","lowest","volume","amount","vibration","updown","updown_yuan"]]

payh.head()
# Out:
#      code       pdate  open  close  highest  lowest  volume       amount  \
# 0  000001  2017-03-01  8.14   8.14     8.20    8.12  346994  330157968.0
# 1  000001  2017-03-02  8.16   8.08     8.19    8.07  403629  382395888.0
# 2  000001  2017-03-03  8.06   8.05     8.08    8.01  342655  321952544.0
# 3  000001  2017-03-06  8.05   8.10     8.11    8.04  404511  381212304.0
# 4  000001  2017-03-07  8.09   8.10     8.11    8.05  294673  277747408.0
#
#    vibration  updown  updown_yuan
# 0       0.98    0.12         0.01
# 1       1.47   -0.74        -0.06
# 2       0.87   -0.37        -0.03
# 3       0.87    0.62         0.05
# 4       0.74    0.00         0.00

# %%
len(payh)
# Out:
# 7856

# %%
df = pd.read_csv("E:\MyGitHub\myPython\QuantPractice\ods\ods_stock_basic_info_full_tbl_init.csv",
                 dtype={'code': str})
codes = df['code'].to_list()

codes[:10]
# Out:
# ['000001',
#  '000002',
#  '000004',
#  '000005',
#  '000006',
#  '000007',
#  '000008',
#  '000009',
#  '000010',
#  '000011']

# %%
aa = ak.stock_zh_a_hist(symbol="000001", period="daily", start_date="19700101", end_date='20500907',
                                        adjust="qfq")
bb = ak.stock_zh_a_hist(symbol="000002", period="daily", start_date="19700101", end_date='20500907',
                                        adjust="qfq")
cc = ak.stock_zh_a_hist(symbol="000004", period="daily", start_date="19700101", end_date='20500907',
                                        adjust="qfq")
dd = ak.stock_zh_a_hist(symbol="000005", period="daily", start_date="19700101", end_date='20500907',
                                        adjust="qfq")

# %%
len(aa), len(bb), len(cc), len(dd)
# Out:
# (7856, 7871, 7718, 7198)

# %%
codes[1:3]
# Out:
# ['000002', '000004']
